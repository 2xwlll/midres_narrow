# %% [markdown]
# # Find Event

# %%
from turbo_seti.find_event.find_event_pipeline import find_event_pipeline

dat_list = (
    "/datax/scratch/wlll2x/"
    "carmen_midres_bliss_combined/"
    "cadence_000/"
    "all.lst"
)

h5_list = (
    "/datax/scratch/wlll2x/"
    "carmen_midres/"
    "cadence_000/"
    "all.lst"
)


events = find_event_pipeline(
    dat_list,
    h5_list,
    filter_threshold=3,
    check_zero_drift=False,
    SNR_cut=10,
    on_off_first="ON",
    number_in_cadence=6,
    saving=True,
    csv_name="carmen_midres_cadence000_events.csv"
)


print(events)
# Out:
# ===========   BEGINNING FIND_EVENT PIPELINE   ===========
#
# Assuming the first observation is an ON
# find_event_pipeline INFO     file=blc73_guppi_58832_08450_NGC7640_0033.gpuspec.0002.dat, tstart=58832.09780092593, source_name=NGC7640, fch1=1688.9634132385254, foff=-0.00286102294921875, nchans=65536
# find_event_pipeline INFO     file=blc73_guppi_58832_08767_HIP115723_0034.gpuspec.0002.dat, tstart=58832.10146990741, source_name=HIP115723, fch1=1688.9634132385254, foff=-0.00286102294921875, nchans=65536
# find_event_pipeline INFO     file=blc73_guppi_58832_09084_NGC7640_0035.gpuspec.0002.dat, tstart=58832.10513888889, source_name=NGC7640, fch1=1688.9634132385254, foff=-0.00286102294921875, nchans=65536
# find_event_pipeline INFO     file=blc73_guppi_58832_09400_HIP115106_0036.gpuspec.0002.dat, tstart=58832.1087962963, source_name=HIP115106, fch1=1688.9634132385254, foff=-0.00286102294921875, nchans=65536
# find_event_pipeline INFO     file=blc73_guppi_58832_09716_NGC7640_0037.gpuspec.0002.dat, tstart=58832.1124537037, source_name=NGC7640, fch1=1688.9634132385254, foff=-0.00286102294921875, nchans=65536
# find_event_pipeline INFO     file=blc73_guppi_58832_10034_HIP115708_0038.gpuspec.0002.dat, tstart=58832.11613425926, source_name=HIP115708, fch1=1688.9634132385254, foff=-0.00286102294921875, nchans=65536
# There are 6 total files in the filelist /datax/scratch/wlll2x/carmen_midres_bliss_combined/cadence_000/all.lst
# Therefore, looking for events in 1 on-off set(s)
# Present in all ON sources with RFI rejection from the OFF sources
# A CSV file will be saved
# === First DAT file in set:  blc73_guppi_58832_08450_NGC7640_0033.gpuspec.0002.dat ===
# find_events: SNR_cut = 10
# find_events: min_drift_rate = None
# find_events: max_drift_rate = None
# find_events: Loading data...
# find_events: Loaded 883 hits from /datax/scratch/wlll2x/carmen_midres_bliss_combined/cadence_000/blc73_guppi_58832_08450_NGC7640_0033.gpuspec.0002.dat (ON)
# find_events: Loaded 1003 hits from /datax/scratch/wlll2x/carmen_midres_bliss_combined/cadence_000/blc73_guppi_58832_08767_HIP115723_0034.gpuspec.0002.dat (OFF)
# find_events: Loaded 1014 hits from /datax/scratch/wlll2x/carmen_midres_bliss_combined/cadence_000/blc73_guppi_58832_09084_NGC7640_0035.gpuspec.0002.dat (ON)
# find_events: Loaded 1078 hits from /datax/scratch/wlll2x/carmen_midres_bliss_combined/cadence_000/blc73_guppi_58832_09400_HIP115106_0036.gpuspec.0002.dat (OFF)
# find_events: Loaded 952 hits from /datax/scratch/wlll2x/carmen_midres_bliss_combined/cadence_000/blc73_guppi_58832_09716_NGC7640_0037.gpuspec.0002.dat (ON)
# find_events: Loaded 1422 hits from /datax/scratch/wlll2x/carmen_midres_bliss_combined/cadence_000/blc73_guppi_58832_10034_HIP115708_0038.gpuspec.0002.dat (OFF)
# find_events: All data loaded!
#
# find_events: Finding events in this cadence...
# find_events (Filter threshold 2/3): Found a total of 2064 hits in this cadence!
# find_events: Found a total of 595 hits in only the on observations for this cadence!
# *** find_events (Filter threshold 3): Found no events across this cadence (in_all_ons_table empty)) :(
# find_events: Elapsed time: 1.76 sec
# find_event_pipeline ERROR    Sorry, no potential candidates with your given parameters :(
# None

# %%
from blimpy import Waterfall

wf = Waterfall("your_file.h5")
h = wf.header

print(h["fch1"])
print(h["foff"])
print(h["nchans"])

fch1 = h["fch1"]
foff = h["foff"]
nchans = h["nchans"]

f_end = fch1 + foff * nchans

print("Start:", fch1)
print("End:", f_end)
# Out:
# your_file.h5
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 3
#       1 from blimpy import Waterfall
# ----> 3 wf = Waterfall("your_file.h5")
#       4 h = wf.header
#       6 print(h["fch1"])
#
# File ~/.conda/envs/willvenv/lib/python3.10/site-packages/blimpy/waterfall.py:167, in Waterfall.__init__(self, filename, f_start, f_stop, t_start, t_stop, load_data, max_load, header_dict, data_array)
#     165 self.filename = filename
#     166 self.ext = os.path.splitext(filename)[-1].lower()
# --> 167 self.container = fw.open_file(filename, f_start=f_start, f_stop=f_stop, t_start=t_start, t_stop=t_stop,
#     168                               load_data=load_data, max_load=max_load)
#     169 self.file_header = self.container.header
#     170 self.header = self.file_header
#
# File ~/.conda/envs/willvenv/lib/python3.10/site-packages/blimpy/io/file_wrapper.py:35, in open_file(filename, f_start, f_stop, t_start, t_stop, load_data, max_load)
#      33     type(filename)
#      34     print(filename)
# ---> 35     raise IOError("No such file or directory: " + filename)
#      37 filename = os.path.expandvars(os.path.expanduser(filename))
#      38 # Get file extension to determine type
#
# OSError: No such file or directory: your_file.h5

# %%
from blimpy import Waterfall
from pathlib import Path

# Base directory containing the cadence folders
BASE = Path("/datax/scratch/wlll2x/carmen_midres")

NCOARSE = 64

for cadence in ["cadence_000", "cadence_001", "cadence_002"]:

    print("=" * 80)
    print(cadence)
    print("=" * 80)

    lst = BASE / cadence / "all.lst"

    with open(lst) as f:
        files = [line.strip() for line in f if line.strip()]

    for filename in files:

        wf = Waterfall(filename, load_data=False)
        h = wf.header

        fch1 = float(h["fch1"])
        foff = float(h["foff"])
        nchans = int(h["nchans"])

        f_end = fch1 + foff * nchans

        bandwidth = abs(foff) * nchans
        coarse_bw = bandwidth / NCOARSE

        print(f"\n{Path(filename).name}")
        print(f"  Source           : {h['source_name']}")
        print(f"  fch1             : {fch1:.6f} MHz")
        print(f"  f_end            : {f_end:.6f} MHz")
        print(f"  nchans           : {nchans}")
        print(f"  foff             : {foff:.9f} MHz/channel")
        print(f"  Total bandwidth  : {bandwidth:.6f} MHz")
        print(f"  Coarse bandwidth : {coarse_bw:.6f} MHz ({NCOARSE} coarse channels)")

print(f"\nFinished {cadence}\n")
# Out:
# ================================================================================
# cadence_000
# ================================================================================
#
# blc73_guppi_58832_08450_NGC7640_0033.gpuspec.0002.h5
#   Source           : NGC7640
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_08767_HIP115723_0034.gpuspec.0002.h5
#   Source           : HIP115723
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_09084_NGC7640_0035.gpuspec.0002.h5
#   Source           : NGC7640
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_09400_HIP115106_0036.gpuspec.0002.h5
#   Source           : HIP115106
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_09716_NGC7640_0037.gpuspec.0002.h5
#   Source           : NGC7640
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_10034_HIP115708_0038.gpuspec.0002.h5
#   Source           : HIP115708
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
# ================================================================================
# cadence_001
# ================================================================================
#
# blc73_guppi_58832_10405_NGC0185_0039.gpuspec.0002.h5
#   Source           : NGC0185
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_10719_HIP2860_0040.gpuspec.0002.h5
#   Source           : HIP2860
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_11033_NGC0185_0041.gpuspec.0002.h5
#   Source           : NGC0185
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_11352_HIP2514_0042.gpuspec.0002.h5
#   Source           : HIP2514
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_11671_NGC0185_0043.gpuspec.0002.h5
#   Source           : NGC0185
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_11989_HIP2596_0044.gpuspec.0002.h5
#   Source           : HIP2596
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
# ================================================================================
# cadence_002
# ================================================================================
#
# blc73_guppi_58832_12338_And_X_0045.gpuspec.0002.h5
#   Source           : And_X
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_12658_HIP4581_0046.gpuspec.0002.h5
#   Source           : HIP4581
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_12978_And_X_0047.gpuspec.0002.h5
#   Source           : And_X
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_13297_HIP4675_0048.gpuspec.0002.h5
#   Source           : HIP4675
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_13616_And_X_0049.gpuspec.0002.h5
#   Source           : And_X
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# blc73_guppi_58832_13933_HIP5599_0050.gpuspec.0002.h5
#   Source           : HIP5599
#   fch1             : 1688.963413 MHz
#   f_end            : 1501.463413 MHz
#   nchans           : 65536
#   foff             : -0.002861023 MHz/channel
#   Total bandwidth  : 187.500000 MHz
#   Coarse bandwidth : 2.929688 MHz (64 coarse channels)
#
# Finished cadence_002

# %% [markdown]
# # Histogram

# %%
import pandas as pd
from pathlib import Path

base = Path("/datax/scratch/wlll2x/carmen_midres_bliss_combined")

for dat in sorted(base.glob("cadence_*/*.dat")):

    # Skip the duplicate combined files
    if dat.name.endswith("_combined.dat"):
        continue

    print("=" * 80)
    print(dat.name)
    print("=" * 80)

    try:
        df = pd.read_csv(
            dat,
            comment="#",
            sep=r"\s+",
            engine="python"
        )

        print("\nColumns:")
        print(df.columns.tolist())

        print("\nFirst five rows:")
        print(df.head())

    except Exception as e:
        print("ERROR:", e)

    # Only inspect the first file
    break
# Out:
# ================================================================================
# blc73_guppi_58832_08450_NGC7640_0033.gpuspec.0002.dat
# ================================================================================
#
# Columns:
# ['000001', '0.000000', '201.782806', '1687.498569', '1687.498569.1', '512', '1687.498569.2', '1687.498569.3', '0.000000.1', '0.000000.2', '0', '2']
#
# First five rows:
#    000001  0.000000  201.782806  1687.498569  1687.498569.1  512  \
# 0       2 -9.584659   99.404144  1687.499995    1687.499995  511
# 1       3  9.584659   98.356880  1687.500005    1687.500005  513
# 2       1 -9.584659  180.947220  1684.570307    1684.570307  507
# 3       2  9.584659  181.865707  1684.570318    1684.570318  509
# 4       1  9.584659  139.776123  1658.203130    1658.203130  473
#
#    1687.498569.2  1687.498569.3  0.000000.1  0.000000.2   0  2
# 0    1687.501431    1687.498559         0.0         0.0   0  3
# 1    1687.498569    1687.501441         0.0         0.0   0  3
# 2    1684.571743    1684.568872         0.0         0.0   1  3
# 3    1684.568882    1684.571753         0.0         0.0   1  3
# 4    1658.201694    1658.204566         0.0         0.0  10  3

# %%
import pandas as pd
from pathlib import Path

dat = Path(
    "/datax/scratch/wlll2x/carmen_midres_bliss_combined/"
    "cadence_000/"
    "blc73_guppi_58832_08450_NGC7640_0033.gpuspec.0002.dat"
)

cols = [
    "Top_Hit",
    "Drift_Rate",
    "SNR",
    "Uncorrected_Frequency",
    "Corrected_Frequency",
    "Index",
    "freq_start",
    "freq_end",
    "SEFD_freq",
    "Coarse_Channel_Number",
    "Full_number_of_hits",
]


df = pd.read_csv(
    dat,
    sep=r"\s+",
    comment="#",
    names=cols,
    header=None,
    engine="python",
)

print(df.head())
print()
print(df.dtypes)
# Out:
#     Top_Hit  Drift_Rate          SNR  Uncorrected_Frequency  \
# 1  0.000000  201.782806  1687.498569            1687.498569
# 2 -9.584659   99.404144  1687.499995            1687.499995
# 3  9.584659   98.356880  1687.500005            1687.500005
# 1 -9.584659  180.947220  1684.570307            1684.570307
# 2  9.584659  181.865707  1684.570318            1684.570318
#
#    Corrected_Frequency        Index   freq_start  freq_end  SEFD_freq  \
# 1                  512  1687.498569  1687.498569       0.0        0.0
# 2                  511  1687.501431  1687.498559       0.0        0.0
# 3                  513  1687.498569  1687.501441       0.0        0.0
# 1                  507  1684.571743  1684.568872       0.0        0.0
# 2                  509  1684.568882  1684.571753       0.0        0.0
#
#    Coarse_Channel_Number  Full_number_of_hits
# 1                      0                    2
# 2                      0                    3
# 3                      0                    3
# 1                      1                    3
# 2                      1                    3
#
# Top_Hit                  float64
# Drift_Rate               float64
# SNR                      float64
# Uncorrected_Frequency    float64
# Corrected_Frequency        int64
# Index                    float64
# freq_start               float64
# freq_end                 float64
# SEFD_freq                float64
# Coarse_Channel_Number      int64
# Full_number_of_hits        int64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path


BASE = Path(
    "/datax/scratch/wlll2x/carmen_midres_bliss_combined"
)

cadences = [
    "cadence_000",
    "cadence_001",
    "cadence_002",
]


cols = [
    "Top_Hit",
    "Drift_Rate",
    "SNR",
    "Uncorrected_Frequency",
    "Corrected_Frequency",
    "Index",
    "freq_start",
    "freq_end",
    "SEFD_freq",
    "Coarse_Channel_Number",
    "Full_number_of_hits",
]


all_drifts = {}


for cadence in cadences:

    print("\n==============================")
    print(cadence)
    print("==============================")

    files = sorted(
        (BASE / cadence).glob("*.dat")
    )

    files = [
        f for f in files
        if "_combined" not in f.name
    ]

    print("Files:", len(files))


    drifts = []


    for dat in files:

        df = pd.read_csv(
            dat,
            sep=r"\s+",
            comment="#",
            names=cols,
            header=None,
            index_col=False,
            engine="python"
        )


        print("\nCHECK:")
        print(
            df[
                [
                    "Top_Hit",
                    "Drift_Rate",
                    "SNR"
                ]
            ].head()
        )


        df["Drift_Rate"] = pd.to_numeric(
            df["Drift_Rate"],
            errors="coerce"
        )


        drifts.extend(
            df["Drift_Rate"].dropna()
        )


    all_drifts[cadence] = drifts


    print("\nHits:", len(drifts))
    print(
        "Min drift:",
        min(drifts)
    )

    print(
        "Max drift:",
        max(drifts)
    )

    print(
        "Unique drift:",
        sorted(set(drifts))
    )



combined = []

for cadence in cadences:
    combined.extend(
        all_drifts[cadence]
    )


print("\n==============================")
print("TOTAL")
print("==============================")

print("Hits:", len(combined))
print("Min:", min(combined))
print("Max:", max(combined))

print(
    sorted(set(combined))
)



plt.figure(figsize=(10,6))

plt.hist(
    combined,
    bins=50
)

plt.xlabel(
    "Drift Rate (Hz/s)"
)

plt.ylabel(
    "Number of Hits"
)

plt.title(
    "BLISS Drift Rate Distribution\nCarmen's Midres"
)

plt.grid()

plt.tight_layout()

plt.savefig(
    "BLISS_drift_hist.png",
    dpi=300
)

plt.show()
# Out:
# ==============================
# cadence_000
# ==============================
# Files: 6
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  201.782806
# 1        2   -9.584659   99.404144
# 2        3    9.584659   98.356880
# 3        1   -9.584659  180.947220
# 4        2    9.584659  181.865707
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  198.110687
# 1        2   -9.584659   95.332939
# 2        3    9.584659   96.360313
# 3        1    9.584659  181.510834
# 4        1    9.584659  137.128769
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  198.652176
# 1        2   -9.584659   97.530075
# 2        3    9.584659   96.371605
# 3        1    9.584659  179.235413
# 4        2   -9.584659  176.772110
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  172.554581
# 1        2   -9.584659   84.998978
# 2        3    9.584659   85.097282
# 3        1    9.584659  163.995499
# 4        1    9.584659  131.104843
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  175.236984
# 1        1    9.584659  164.141037
# 2        1    9.584659  135.642502
# 3        2   -9.584659  136.205261
# 4        1    9.584659  145.686783
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  146.762314
# 1        2   -9.584659   71.241287
# 2        3    9.584659   72.979691
# 3        1    9.584659  120.052246
# 4        1    9.584659  115.277924
#
# Hits: 6352
# Min drift: -9.584659
# Max drift: 9.584659
# Unique drift: [-9.584659, 0.0, 9.584659]
#
# ==============================
# cadence_001
# ==============================
# Files: 6
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  191.645279
# 1        2    9.584659   93.279800
# 2        1    9.584659  176.344620
# 3        1    9.584659  134.922989
# 4        2   -9.584659  134.525330
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  195.300735
# 1        2    9.584659   94.605659
# 2        1    9.584659  183.588211
# 3        1    9.584659  138.002106
# 4        1    9.584659  147.833618
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  181.992859
# 1        2    9.584659   89.638260
# 2        1   -9.584659  164.331375
# 3        2    9.584659  166.845871
# 4        1    9.584659  127.640610
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  188.922546
# 1        2   -9.584659   92.565041
# 2        3    9.584659   91.646721
# 3        1    9.584659  172.828796
# 4        1    9.584659  142.159317
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  176.508209
# 1        2   -9.584659   85.244888
# 2        3    9.584659   85.864784
# 3        1   -9.584659  161.846970
# 4        2    9.584659  164.078873
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  196.303528
# 1        2   -9.584659   94.574394
# 2        3    9.584659   94.389198
# 3        1    9.584659  175.543869
# 4        2   -9.584659  174.607544
#
# Hits: 4234
# Min drift: -9.584659
# Max drift: 9.584659
# Unique drift: [-9.584659, 0.0, 9.584659]
#
# ==============================
# cadence_002
# ==============================
# Files: 6
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  181.900757
# 1        2    9.584659   88.081459
# 2        3   -9.584659   87.482178
# 3        1    9.584659  175.281509
# 4        1    9.584659  138.597260
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  201.040894
# 1        2   -9.584659   98.860947
# 2        3    9.584659   99.418365
# 3        1   -9.584659  184.341782
# 4        2    9.584659  184.848312
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  198.395676
# 1        2   -9.584659   97.750626
# 2        3    9.584659   98.369644
# 3        1   -9.584659  182.886337
# 4        2    9.584659  183.246521
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  202.049454
# 1        2    9.584659   98.294579
# 2        1   -9.584659  184.110336
# 3        2    9.584659  185.350311
# 4        1    9.584659  140.896317
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  198.528900
# 1        2    9.584659   96.506828
# 2        1   -9.584659  183.148956
# 3        2    9.584659  185.957932
# 4        1    9.584659  143.315964
#
# CHECK:
#    Top_Hit  Drift_Rate         SNR
# 0        1    0.000000  199.286819
# 1        2   -9.584659   97.109001
# 2        3    9.584659   98.730820
# 3        1    9.584659  181.300766
# 4        1    9.584659  138.234802
#
# Hits: 4090
# Min drift: -9.584659
# Max drift: 9.584659
# Unique drift: [-9.584659, 0.0, 9.584659]
#
# ==============================
# TOTAL
# ==============================
# Hits: 14676
# Min: -9.584659
# Max: 9.584659
# [-9.584659, 0.0, 9.584659]
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(
# /tmp/ipykernel_1727003/1801897991.py:58: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(

# %% [markdown]
# # different bliss runs

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from collections import Counter


DATA_DIR = Path(
    "/datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift"
)


files = sorted(DATA_DIR.rglob("*_combined.dat"))

print("Files:", len(files))


all_drifts = []
file_drifts = {}


for dat in files:

    print("\n==============================")
    print(dat)
    print("==============================")


    df = pd.read_csv(
        dat,
        sep=r"\s+",
        comment="#",
        header=None,
        engine="python"
    )


    print(df.iloc[:,0:4].head())


    # =====================================
    # Correct BLISS drift column
    # =====================================

    drifts = pd.to_numeric(
        df.iloc[:,1],
        errors="coerce"
    ).dropna()


    file_drifts[dat.name] = drifts.tolist()

    all_drifts.extend(
        drifts.tolist()
    )


    print()
    print("Hits:", len(drifts))
    print("Min drift:", min(drifts))
    print("Max drift:", max(drifts))
    print("Sample drift:", sorted(set(drifts))[:20])



print("\n==============================")
print("TOTAL")
print("==============================")


print(
    "Total hits:",
    len(all_drifts)
)

print(
    "Min:",
    min(all_drifts)
)

print(
    "Max:",
    max(all_drifts)
)

print(
    "Unique drift sample:"
)

print(
    sorted(set(all_drifts))[:50]
)



# Histogram

plt.figure(figsize=(10,6))

plt.hist(
    all_drifts,
    bins=100
)

plt.xlabel(
    "Drift Rate (Hz/s)"
)

plt.ylabel(
    "Number of Hits"
)

plt.title(
    "BLISS Drift Rate Distribution\n"
    "Carmen's Midres Middrift"
)

plt.grid()

plt.tight_layout()

plt.savefig(
    "carmen_midres_middrift_hist.png",
    dpi=300
)

plt.show()



# Exact BLISS drift grid occupancy

counts = Counter(all_drifts)

plt.figure(figsize=(12,6))

plt.bar(
    counts.keys(),
    counts.values()
)

plt.xlabel(
    "Drift Rate (Hz/s)"
)

plt.ylabel(
    "Number of Hits"
)

plt.title(
    "BLISS Drift Template Occupancy\n"
    "Carmen's Midres Middrift"
)

plt.grid()

plt.tight_layout()

plt.savefig(
    "carmen_midres_middrift_grid.png",
    dpi=300
)

plt.show()
# Out:
# Files: 18
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_000/blc73_guppi_58832_08450_NGC7640_0033.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  201.782806  1687.498569
# 1  2 -28.753978   64.338753  1687.499985
# 2  3  28.753978   64.035973  1687.500015
# 3  4  -9.584659   99.404144  1687.499995
# 4  5  38.338637   46.910152  1687.498590
#
# Hits: 2112
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_000/blc73_guppi_58832_08767_HIP115723_0034.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  198.110687  1687.498569
# 1  2  28.753978   62.111221  1687.500015
# 2  3 -28.753978   61.161114  1687.499985
# 3  4  -9.584659   95.332939  1687.499995
# 4  5  38.338637   45.586300  1687.498590
#
# Hits: 2159
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_000/blc73_guppi_58832_09084_NGC7640_0035.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1  28.753978   64.482719  1687.500015
# 1  2   0.000000  198.652176  1687.498569
# 2  3 -28.753978   64.279457  1687.499985
# 3  4  -9.584659   97.530075  1687.499995
# 4  5  19.169318   97.206543  1687.498580
#
# Hits: 2314
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_000/blc73_guppi_58832_09400_HIP115106_0036.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1  28.753978   55.279076  1687.500015
# 1  2   0.000000  172.554581  1687.498569
# 2  3 -28.753978   55.699322  1687.499985
# 3  4  -9.584659   84.998978  1687.499995
# 4  5   9.584659   85.097282  1687.500005
#
# Hits: 2104
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_000/blc73_guppi_58832_09716_NGC7640_0037.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  175.236984  1687.498569
# 1  1 -28.753978  106.859200  1684.570297
# 2  2  28.753978  107.876968  1684.570328
# 3  3   9.584659  164.141037  1684.570318
# 4  4  38.338637   82.585808  1684.568903
#
# Hits: 2299
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_000/blc73_guppi_58832_10034_HIP115708_0038.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  146.762314  1687.498569
# 1  2  -9.584659   71.241287  1687.499995
# 2  3   9.584659   72.979691  1687.500005
# 3  1 -28.753978   78.474251  1684.570297
# 4  2  28.753978   78.090904  1684.570328
#
# Hits: 2329
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_001/blc73_guppi_58832_10405_NGC0185_0039.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  191.645279  1687.498569
# 1  2 -28.753978   60.189701  1687.499985
# 2  3  28.753978   61.111767  1687.500015
# 3  4 -38.338637   43.672668  1687.498549
# 4  5  19.169318   93.929749  1687.498580
#
# Hits: 1711
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_001/blc73_guppi_58832_10719_HIP2860_0040.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  195.300735  1687.498569
# 1  2  28.753978   61.517719  1687.500015
# 2  3 -28.753978   61.480900  1687.499985
# 3  4  19.169318   94.714394  1687.498580
# 4  5 -19.169318   94.492004  1687.498559
#
# Hits: 2257
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_001/blc73_guppi_58832_11033_NGC0185_0041.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1 -28.753978   57.360119  1687.499985
# 1  2   0.000000  181.992859  1687.498569
# 2  3  28.753978   58.220634  1687.500015
# 3  4 -19.169318   88.199173  1687.498559
# 4  5   9.584659   89.638260  1687.500005
#
# Hits: 1345
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_001/blc73_guppi_58832_11352_HIP2514_0042.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  188.922546  1687.498569
# 1  2 -28.753978   58.840599  1687.499985
# 2  3  28.753978   58.783424  1687.500015
# 3  4  -9.584659   92.565041  1687.499995
# 4  5   9.584659   91.646721  1687.500005
#
# Hits: 1505
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_001/blc73_guppi_58832_11671_NGC0185_0043.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  176.508209  1687.498569
# 1  2 -28.753978   54.137802  1687.499985
# 2  3  28.753978   54.270313  1687.500015
# 3  4  -9.584659   85.244888  1687.499995
# 4  5  38.338637   40.110611  1687.498590
#
# Hits: 1433
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_001/blc73_guppi_58832_11989_HIP2596_0044.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  196.303528  1687.498569
# 1  2  28.753978   59.632965  1687.500015
# 2  3 -28.753978   61.201382  1687.499985
# 3  4  -9.584659   94.574394  1687.499995
# 4  5  38.338637   43.666496  1687.498590
#
# Hits: 1484
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_002/blc73_guppi_58832_12338_And_X_0045.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1  28.753978   56.024010  1687.500015
# 1  2   0.000000  181.900757  1687.498569
# 2  3 -28.753978   56.974583  1687.499985
# 3  4  -9.584659   87.482178  1687.499995
# 4  5  38.338637   40.693207  1687.498590
#
# Hits: 1670
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_002/blc73_guppi_58832_12658_HIP4581_0046.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1  28.753978   63.964661  1687.500015
# 1  2   0.000000  201.040894  1687.498569
# 2  3 -28.753978   64.039215  1687.499985
# 3  4  -9.584659   98.860947  1687.499995
# 4  5  38.338637   47.619362  1687.498590
#
# Hits: 1391
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_002/blc73_guppi_58832_12978_And_X_0047.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  198.395676  1687.498569
# 1  2 -28.753978   64.330742  1687.499985
# 2  3  28.753978   63.465054  1687.500015
# 3  4  -9.584659   97.750626  1687.499995
# 4  5 -38.338637   47.116600  1687.498549
#
# Hits: 2168
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_002/blc73_guppi_58832_13297_HIP4675_0048.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  202.049454  1687.498569
# 1  2 -28.753978   63.712471  1687.499985
# 2  3  38.338637   46.569168  1687.498590
# 3  4 -19.169318   99.426361  1687.498559
# 4  5  28.753978   63.538807  1687.500015
#
# Hits: 1525
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_002/blc73_guppi_58832_13616_And_X_0049.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  198.528900  1687.498569
# 1  2 -28.753978   61.877499  1687.499985
# 2  3  28.753978   62.341015  1687.500015
# 3  4 -38.338637   46.260345  1687.498549
# 4  5   9.584659   96.506828  1687.500005
#
# Hits: 1379
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_middrift/cadence_002/blc73_guppi_58832_13933_HIP5599_0050.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1  28.753978   63.457664  1687.500015
# 1  2   0.000000  199.286819  1687.498569
# 2  3 -28.753978   62.576393  1687.499985
# 3  4  -9.584659   97.109001  1687.499995
# 4  5   9.584659   98.730820  1687.500005
#
# Hits: 1624
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# TOTAL
# ==============================
# Total hits: 32809
# Min: -38.338637
# Max: 38.338637
# Unique drift sample:
# [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from collections import Counter


DATA_DIR = Path(
    "/datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift"
)


files = sorted(DATA_DIR.rglob("*_combined.dat"))

print("Files:", len(files))


all_drifts = []
file_drifts = {}


for dat in files:

    print("\n==============================")
    print(dat)
    print("==============================")


    df = pd.read_csv(
        dat,
        sep=r"\s+",
        comment="#",
        header=None,
        engine="python"
    )


    print(df.iloc[:,0:4].head())


    # =====================================
    # Correct BLISS drift column
    # =====================================

    drifts = pd.to_numeric(
        df.iloc[:,1],
        errors="coerce"
    ).dropna()


    file_drifts[dat.name] = drifts.tolist()

    all_drifts.extend(
        drifts.tolist()
    )


    print()
    print("Hits:", len(drifts))
    print("Min drift:", min(drifts))
    print("Max drift:", max(drifts))
    print("Sample drift:", sorted(set(drifts))[:20])



print("\n==============================")
print("TOTAL")
print("==============================")


print(
    "Total hits:",
    len(all_drifts)
)

print(
    "Min:",
    min(all_drifts)
)

print(
    "Max:",
    max(all_drifts)
)

print(
    "Unique drift sample:"
)

print(
    sorted(set(all_drifts))[:50]
)



# Histogram

plt.figure(figsize=(10,6))

plt.hist(
    all_drifts,
    bins=100
)

plt.xlabel(
    "Drift Rate (Hz/s)"
)

plt.ylabel(
    "Number of Hits"
)

plt.title(
    "BLISS Drift Rate Distribution\n"
    "Carmen's Midres Highdrift"
)

plt.grid()

plt.tight_layout()

plt.savefig(
    "carmen_midres_highdrift_hist.png",
    dpi=300
)

plt.show()



# Exact BLISS drift grid occupancy

counts = Counter(all_drifts)

plt.figure(figsize=(12,6))

plt.bar(
    counts.keys(),
    counts.values()
)

plt.xlabel(
    "Drift Rate (Hz/s)"
)

plt.ylabel(
    "Number of Hits"
)

plt.title(
    "BLISS Drift Template Occupancy\n"
    "Carmen's Midres Highdrift"
)

plt.grid()

plt.tight_layout()

plt.savefig(
    "carmen_midres_highdrift_grid.png",
    dpi=300
)

plt.show()
# Out:
# Files: 18
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_000/blc73_guppi_58832_08450_NGC7640_0033.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   98.356880  1687.500005
# 1  2 -47.923296   38.264225  1687.499974
# 2  3  38.338637   46.910152  1687.498590
# 3  4   0.000000  201.782806  1687.498569
# 4  5  -9.584659   99.404144  1687.499995
#
# Hits: 3064
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_000/blc73_guppi_58832_08767_HIP115723_0034.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   96.360313  1687.500005
# 1  2 -47.923296   34.636284  1687.499974
# 2  3   0.000000  198.110687  1687.498569
# 3  4 -38.338637   45.223022  1687.498549
# 4  5  38.338637   45.586300  1687.498590
#
# Hits: 3181
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_000/blc73_guppi_58832_09084_NGC7640_0035.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1 -47.923296   37.806671  1687.499974
# 1  2  38.338637   48.541115  1687.498590
# 2  3  -9.584659   97.530075  1687.499995
# 3  4  47.923296   37.635796  1687.500026
# 4  5   0.000000  198.652176  1687.498569
#
# Hits: 3323
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_000/blc73_guppi_58832_09400_HIP115106_0036.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   85.097282  1687.500005
# 1  2   0.000000  172.554581  1687.498569
# 2  3  -9.584659   84.998978  1687.499995
# 3  4 -28.753978   55.699322  1687.499985
# 4  5  28.753978   55.279076  1687.500015
#
# Hits: 3062
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_000/blc73_guppi_58832_09716_NGC7640_0037.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   0.000000  175.236984  1687.498569
# 1  1 -47.923296   61.611526  1684.570287
# 2  2 -19.169318  160.913223  1684.568872
# 3  3  38.338637   82.585808  1684.568903
# 4  4  28.753978  107.876968  1684.570328
#
# Hits: 3337
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_000/blc73_guppi_58832_10034_HIP115708_0038.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   72.979691  1687.500005
# 1  2   0.000000  146.762314  1687.498569
# 2  3  -9.584659   71.241287  1687.499995
# 3  1   9.584659  120.052246  1684.570318
# 4  2  67.092614   33.022667  1684.570349
#
# Hits: 3339
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_001/blc73_guppi_58832_10405_NGC0185_0039.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1 -19.169318   94.433662  1687.498559
# 1  2   0.000000  191.645279  1687.498569
# 2  3  38.338637   43.195538  1687.498590
# 3  4 -38.338637   43.672668  1687.498549
# 4  5  19.169318   93.929749  1687.498580
#
# Hits: 2465
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_001/blc73_guppi_58832_10719_HIP2860_0040.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1 -19.169318   94.492004  1687.498559
# 1  2   0.000000  195.300735  1687.498569
# 2  3  19.169318   94.714394  1687.498580
# 3  4 -28.753978   61.480900  1687.499985
# 4  5  28.753978   61.517719  1687.500015
#
# Hits: 3282
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_001/blc73_guppi_58832_11033_NGC0185_0041.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   89.638260  1687.500005
# 1  2 -19.169318   88.199173  1687.498559
# 2  3   0.000000  181.992859  1687.498569
# 3  4 -28.753978   57.360119  1687.499985
# 4  5  28.753978   58.220634  1687.500015
#
# Hits: 2000
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_001/blc73_guppi_58832_11352_HIP2514_0042.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   91.646721  1687.500005
# 1  2   0.000000  188.922546  1687.498569
# 2  3  -9.584659   92.565041  1687.499995
# 3  4  28.753978   58.783424  1687.500015
# 4  5 -28.753978   58.840599  1687.499985
#
# Hits: 2316
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_001/blc73_guppi_58832_11671_NGC0185_0043.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   85.864784  1687.500005
# 1  2  38.338637   40.110611  1687.498590
# 2  3 -38.338637   38.488998  1687.498549
# 3  4   0.000000  176.508209  1687.498569
# 4  5  -9.584659   85.244888  1687.499995
#
# Hits: 2176
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_001/blc73_guppi_58832_11989_HIP2596_0044.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   94.389198  1687.500005
# 1  2  38.338637   43.666496  1687.498590
# 2  3   0.000000  196.303528  1687.498569
# 3  4 -38.338637   45.296749  1687.498549
# 4  5  28.753978   59.632965  1687.500015
#
# Hits: 2201
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_002/blc73_guppi_58832_12338_And_X_0045.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   88.081459  1687.500005
# 1  2  38.338637   40.693207  1687.498590
# 2  3   0.000000  181.900757  1687.498569
# 3  4  -9.584659   87.482178  1687.499995
# 4  5  28.753978   56.024010  1687.500015
#
# Hits: 2502
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_002/blc73_guppi_58832_12658_HIP4581_0046.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   99.418365  1687.500005
# 1  2 -47.923296   36.356270  1687.499974
# 2  3  38.338637   47.619362  1687.498590
# 3  4   0.000000  201.040894  1687.498569
# 4  5  -9.584659   98.860947  1687.499995
#
# Hits: 2035
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_002/blc73_guppi_58832_12978_And_X_0047.gpuspec.0002_combined.dat
# ==============================
#    0          1          2            3
# 0  1   9.584659  98.369644  1687.500005
# 1  2  38.338637  47.134567  1687.498590
# 2  3  -9.584659  97.750626  1687.499995
# 3  4 -38.338637  47.116600  1687.498549
# 4  5 -28.753978  64.330742  1687.499985
#
# Hits: 3158
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_002/blc73_guppi_58832_13297_HIP4675_0048.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1 -19.169318   99.426361  1687.498559
# 1  2   0.000000  202.049454  1687.498569
# 2  3  38.338637   46.569168  1687.498590
# 3  4  19.169318   98.789261  1687.498580
# 4  5 -28.753978   63.712471  1687.499985
#
# Hits: 2212
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_002/blc73_guppi_58832_13616_And_X_0049.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   96.506828  1687.500005
# 1  2 -19.169318   96.587669  1687.498559
# 2  3   0.000000  198.528900  1687.498569
# 3  4  38.338637   46.666962  1687.498590
# 4  5 -28.753978   61.877499  1687.499985
#
# Hits: 2051
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# /datax/scratch/wlll2x/carmen_midres_bliss_combined_highdrift/cadence_002/blc73_guppi_58832_13933_HIP5599_0050.gpuspec.0002_combined.dat
# ==============================
#    0          1           2            3
# 0  1   9.584659   98.730820  1687.500005
# 1  2   0.000000  199.286819  1687.498569
# 2  3  -9.584659   97.109001  1687.499995
# 3  4  28.753978   63.457664  1687.500015
# 4  5 -28.753978   62.576393  1687.499985
#
# Hits: 2388
# Min drift: -86.261933
# Max drift: 86.261933
# Sample drift: [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]
#
# ==============================
# TOTAL
# ==============================
# Total hits: 48092
# Min: -86.261933
# Max: 86.261933
# Unique drift sample:
# [-86.261933, -76.677274, -67.092614, -57.507955, -47.923296, -38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637, 47.923296, 57.507955, 67.092614, 76.677274, 86.261933]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from collections import Counter


DATA_DIR = Path(
    "/datax/scratch/wlll2x/mars_midres_bliss_combined"
)


files = sorted(DATA_DIR.rglob("*_combined.dat"))

print("Files:", len(files))


all_drifts = []
file_drifts = {}


for dat in files:

    print("\n==============================")
    print(dat)
    print("==============================")


    df = pd.read_csv(
        dat,
        sep=r"\s+",
        comment="#",
        header=None,
        engine="python"
    )


    print(df.iloc[:,0:4].head())


    # =====================================
    # Correct BLISS drift column
    # =====================================

    drifts = pd.to_numeric(
        df.iloc[:,1],
        errors="coerce"
    ).dropna()


    file_drifts[dat.name] = drifts.tolist()

    all_drifts.extend(
        drifts.tolist()
    )


    print()
    print("Hits:", len(drifts))
    print("Min drift:", min(drifts))
    print("Max drift:", max(drifts))
    print("Sample drift:", sorted(set(drifts))[:20])



print("\n==============================")
print("TOTAL")
print("==============================")


print(
    "Total hits:",
    len(all_drifts)
)

print(
    "Min:",
    min(all_drifts)
)

print(
    "Max:",
    max(all_drifts)
)

print(
    "Unique drift sample:"
)

print(
    sorted(set(all_drifts))[:50]
)



# Histogram

plt.figure(figsize=(10,6))

plt.hist(
    all_drifts,
    bins=100
)

plt.xlabel(
    "Drift Rate (Hz/s)"
)

plt.ylabel(
    "Number of Hits"
)

plt.title(
    "BLISS Drift Rate Distribution\n"
    "gb_mars Downlink Midres"
)

plt.grid()

plt.tight_layout()

plt.savefig(
    "mars_midres_combined_hist.png",
    dpi=300
)

plt.show()



# Exact BLISS drift grid occupancy

counts = Counter(all_drifts)

plt.figure(figsize=(12,6))

plt.bar(
    counts.keys(),
    counts.values()
)

plt.xlabel(
    "Drift Rate (Hz/s)"
)

plt.ylabel(
    "Number of Hits"
)

plt.title(
    "Bliss Drift Rate Distribution\n"
    "Mars Midres Middrift"
)

plt.grid()

plt.tight_layout()

plt.savefig(
    "mars_midres_combined_hist.png",
    dpi=300
)

plt.show()
# Out:
# Files: 6
#
# ==============================
# /datax/scratch/wlll2x/mars_midres_bliss_combined/h5spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66265_DIAG_Mars2020_0011.rawspec.0002_combined.dat
# ==============================
#    0          1             2             3
# 0  1  28.753978  1.917117e+02  11249.403492
# 1  2  28.753978  1.191974e+02  11249.706761
# 2  3  28.753978  5.136894e+03  11249.706761
# 3  4  28.753978  5.461246e+06  11249.995724
# 4  5 -28.753978  5.136894e+03  11250.298961
#
# Hits: 8828
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/mars_midres_bliss_combined/h5spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66578_DIAG_Mars_0012.rawspec.0002_combined.dat
# ==============================
#    0          1           2             3
# 0  1   9.584659  171.787262  11250.293260
# 1  2  28.753978  194.680344  11249.403492
# 2  3  38.338637  146.472794  11250.597974
# 3  4  38.338637   89.319328  11250.597974
# 4  5  38.338637   38.037338  11250.597974
#
# Hits: 8330
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/mars_midres_bliss_combined/h5spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66892_DIAG_Mars2020_0013.rawspec.0002_combined.dat
# ==============================
#    0          1            2             3
# 0  1 -28.753978   115.840508  11249.718174
# 1  2 -28.753978  5930.486328  11249.698147
# 2  3  -9.584659   167.650757  11249.718184
# 3  4  -9.584659   217.856750  11249.403472
# 4  5 -28.753978   191.726059  11249.400600
#
# Hits: 9105
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/mars_midres_bliss_combined/h5spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67205_DIAG_Mars_0014.rawspec.0002_combined.dat
# ==============================
#    0          1            2             3
# 0  1  28.753978   117.858589  11249.706761
# 1  2  28.753978  5157.186035  11249.706761
# 2  3   9.584659   167.991882  11250.293260
# 3  4  28.753978   194.632645  11249.403492
# 4  5  38.338637   146.593506  11250.597974
#
# Hits: 9375
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/mars_midres_bliss_combined/h5spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67519_DIAG_Mars2020_0015.rawspec.0002_combined.dat
# ==============================
#    0          1            2             3
# 0  1  28.753978   116.479301  11249.706761
# 1  2  28.753978  5111.307617  11249.706761
# 2  3  38.338637   142.590744  11250.597974
# 3  4  38.338637    89.605438  11250.597974
# 4  5  38.338637    37.198086  11250.597974
#
# Hits: 9156
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# /datax/scratch/wlll2x/mars_midres_bliss_combined/h5spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67832_DIAG_Mars_0016.rawspec.0002_combined.dat
# ==============================
#    0          1            2             3
# 0  1  28.753978   196.930740  11249.403492
# 1  2  28.753978   118.658081  11249.706761
# 2  3  28.753978  5151.604980  11249.706761
# 3  4  -9.584659   169.145294  11249.718184
# 4  5  38.338637   146.444870  11249.402067
#
# Hits: 10279
# Min drift: -38.338637
# Max drift: 38.338637
# Sample drift: [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
#
# ==============================
# TOTAL
# ==============================
# Total hits: 55073
# Min: -38.338637
# Max: 38.338637
# Unique drift sample:
# [-38.338637, -28.753978, -19.169318, -9.584659, 0.0, 9.584659, 19.169318, 28.753978, 38.338637]
